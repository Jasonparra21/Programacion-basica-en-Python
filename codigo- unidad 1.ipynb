# %%
print('hola, putas')
nombre = input('ingrese su nombre ')
mensaje = f"¡Hola {nombre}!"
print(mensaje)
# cadenas de texto 
# \n cambio de linea 
# \t espacio de tabulacion
# .format() igual que f""
#mayisculas .upper()
#minisculas .lower()}
# .count cuenta caracteres
# .replace remplaza caracteres por otros
#{nombre:16} otorga 16 espacios
# Out:
# hola, putas
# ingrese su nombre Jei
# ¡Hola Jei!

# %%
cadena = None
cadena = input('cadena de entrada ')
# 1) Convierte las minúsculas en mayúsculas.

cadena = cadena.upper()


# 2) Reemplaza la letra 'O' por 'OOO'.

cadena = cadena.replace('O', 'O'*3)


# 3) Añade los signos de exclamación "!!!!!" al final.

cadena = f"{cadena}!!!!!"


# Envía el resultado a la salida con la función 'print'.


print(cadena)

## ☝️ Escriba su código ENCIMA de esta línea ☝️ ##




## conversion de caracteres
## str()
## int()
#a+=+1 ---> a=a+1
# Out:
# cadena de entrada Jeisson
# JEISSOOON!!!!!

# %%
import math
math.ceil(1.2)
##################################################
####   💻  Práctica: Dividir en grupos  💻  #####
##################################################

## 👇 Escriba su código DEBAJO de esta línea 👇 ##


# Reciba n y x de la entrada con la función 'input'. 
# No olvide convertir las cadenas en números con 'int'.
n = None
x = None
n=int(input())
x=int(input())

# Calcula el número de grupos de tamaño x que se pueden formar.

s1= n//x



# Calcula el número de estudiantes sobrantes asignados a la calificación.
# (Este número debe ser menor que x)

s2= (n-(s1*x))


# Calcula el número de reportes entregados por los estudiantes.

s3 = (n-(s1*x))*s1


# Imprime en la salida el número correspondiente para las preguntas del enunciado.

print(s1)
print(s3)


## ☝️ Escriba su código ENCIMA de esta línea ☝️ ##



## cantidad de decimales :10f
# Out:
# 20
# 3
# 6
# 12

# %%
##################################################
### 💻  Ejemplo: Ejercicios de física (I)  💻 ###
##################################################

## 👇 Escriba su código DEBAJO de esta línea 👇 ##


# 1) Obtener de la entrada del programa los parámetros iniciales.


x0 = None
v0 = None
a = None
t = None
x0 = input('x0')
v0 = input('v0')
a = input('a')
t = input('t')


# 2) Convertir cada valor de texto obtenido de la entrada en un valor numérico decimal.
x0=float(x0)
v0=float(v0)
a=float(a)
t=float(t)
# 3) Utilizar los valores numéricos en una expresión matemática y obtener el valor de la posición final.

x = None
x=x0+v0*t+(1/2)*a*(t**2)

# 4) Reportar el resultado de la operación con dos dígitos decimales.

print(f"La posición final es {x:.2f} metros.")
# Out:
# x021.1
# v040
# a0.1
# t60
# 2601.10

# %%
##################################################
#### 💻 Tarea: Ejercicios de física (II)  💻 ####
##################################################

## 👇 Escriba su código DEBAJO de esta línea 👇 ##


# 1) Obtener de la entrada del programa los parámetros iniciales.


x0 = None
v0 = None
a = None
t = None

x0 = float(input())
v0 = float(input())
a = float(input())
t = float(input())

# 2) Convertir cada valor de texto obtenido de la entrada en un valor numérico decimal.





# 3) Realizar las operaciones matemáticas para las conversiones de unidad de medida necesarias.


v01= v0*(1/3.6)
akh=a*12960 
th=t*(1/3600)
# 4) Utilizar los valores numéricos en las expresiones matemáticas de cada ecuación y obtener el valor de:


#     i. Posición final 
x=x0+v01*t+(1/2)*a*(t**2) 

#     ii. Velocidad final.
v = v0 +(akh*th)

# 5) Reportar el resultado de la operación con el formato solicitado.

print(f'La posición final es de {x:.2f} m y la velocidad es de {v:.3f} km/h')

## ☝️ Escriba su código ENCIMA de esta línea ☝️ ##
# Out:
# 47
# 6
# 5e-2
# 147
# La posición final es de 832.23 m y la velocidad es de 32.460 km/h

# %%
numero=int(input()) 

# Operación matemática y asignación (~ 1 línea).
numero=numero+1

# Salida del programa (~ 1 línea).
print(numero)
# Out:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-8d0e86670f69> in <module>()
#       2
#       3 # Operación matemática y asignación (~ 1 línea).
# ----> 4 numero=numero+1
#       5
#       6 # Salida del programa (~ 1 línea).
#
# TypeError: can only concatenate str (not "int") to str

# %%
### ESCRIBA SU CÓDIGO A PARTIR DE AQUÍ ### (~ 11 líneas de código)

# Entrada del programa (~ 1 línea).
cadena = input()           # Reemplace 'None' por el código necesario. 

# Operaciones en cadenas de texto (~ 9 líneas)
resultado=cadena.lower()
resultado = resultado.replace('a','i')
resultado = resultado.replace('á','í')
resultado = resultado.replace('e','i')
resultado = resultado.replace('é','í')
resultado = resultado.replace('o','i')
resultado = resultado.replace('ó','í')
# Salida del programa (~ 1 línea).
print(resultado)
# Out:
# Holaaa
# Hiliii

# %%
import math
ventas = int(input())                
# Operaciones matemáticas (~ 3 líneas).
monto_integrante = ((ventas/7)*2)
monto_integrante=math.floor(monto_integrante)
monto_sobrante = (((ventas/7)*2)-monto_integrante)*7
monto_sobrante=round(monto_sobrante)
# Salida del programa (~ 2 líneas).
print(monto_integrante)          # Indique el primer resultado en esta línea.
print(monto_sobrante)            # Indique el segundo resultado en esta línea.
# Out:
# 110
# 31
# 3

# %%
a
# Out:
# 2000
# No es un año bisiesto

# %%
print(c3)
# Out:
# True
