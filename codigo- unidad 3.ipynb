# %%
color =input()
color = color[1:]
int(color, 16)
lista= [color [:2],color [2:-2] ,color[-2:]]
print(f'R: {int(lista[0], 16)} G: {int(lista[1], 16)} B: {int(lista[2], 16)}')
# Out:
# #6e00ff
# R: 110 G: 0 B: 255

# %%
mul = []
vector_u = [int(elemento) for elemento in input().split()]
vector_v = [int(elemento) for elemento in input().split()]
i=0
j=0
b=0
while i != len(vector_u):
   mul.append(vector_v[i]*vector_u[i])
   i=i+1
for j in range(0,(len(mul))):
  a=mul[j]
  b=b+a
print(b)
# Out:
# -32 -4 -13 -36 -7
# -22 20 37 11 -38
# 13

# %%
# MEJORADO 
mul = []
vector_u = [int(elemento) for elemento in input().split()]
vector_v = [int(elemento) for elemento in input().split()]
i=0
b=0
for i in range(0,(len(vector_u))):
  mul.append(vector_v[i]*vector_u[i])
  a=mul[i]
  b=b+a
print(b)
# Out:
# -32 -4 -13 -36 -7
# -22 20 37 11 -38
# 13

# %%
num_entradas = int(input())
c=0
candidatos={}
for x in range(num_entradas):
   nombres=input()
   if nombres in candidatos:
     candidatos[nombres]+=1
   else:
     candidatos[nombres]=1 
maxc=max(candidatos.values())
for i in candidatos:
     if(maxc==candidatos[i]):
       c+=1
     if(c>1):
       break
if c>=2:
   print("EMPATE")
else:  
    print(max(candidatos, key=candidatos.get))
# Out:
# 4
# d
# d
# d
# f
# 3
# d
# 1
# f
# d

# %%
a=set(input().split())
b=set(input().split())
inter=a & b
dif=b^a
print(len(inter))
print(len(dif))

# %%
inicio=""
A={}
tem=""
while inicio!="detener":
      inicio=input('') 
      if inicio== "añadir":
        tem=[input()]
        Ar=input()
        if Ar in A:
         A[Ar]+=(tem)
        else:
         A[Ar]=tem
      elif inicio== "reproducir":
        ar=input()
        for i in A:
           if i != ar:
             print('El artista no tiene canciones registradas.')
           else: 
             if (A[ar])!=[]:
               cancion=(A[ar]).pop()
               print(f'Reproduciendo {cancion} de {ar}.')
             else :
               print('No quedan canciones en cola.')
      elif inicio!='añadir' and inicio!='reproducir' and inicio!='detener' :
        print('Comando no reconocido. Intente de nuevo:')     


print('Terminando la sesión. ¡Hasta pronto!')
# Out:
# detener
# Terminando la sesión. ¡Hasta pronto!

# %%
canciones = dict()
while True:
  command = input()
  if command =='añadir':
     cancion = input()
     artista = input()
     if artista not in canciones:
       canciones [artista]=list()
     canciones[artista].append(cancion)
  elif command =='reproducir':
    artista=input()
    if artista in canciones:
       if len(canciones[artista])>0:
          cancion = canciones[artista].pop(0)
          print(f'Reproduciendo {cancion} de {artista}.')
          canciones[artista].append(cancion)
       else:
            print(f"No quedan canciones en cola.")
    else:
      print('El artista no tiene canciones registradas.')
  elif command == 'listar':
     canta=input()
     if canta in artista:
       listado = canciones[artista]
       larlist=len(listado)
       for i in range(larlist):
          print(f"{i+1}. {listado[i]}")
  elif command =='detener':
    print('Terminando la sesión. ¡Hasta pronto!')
    break
  else:
    print('Comando no reconocido. Intente de nuevo:')
# Out:
# añadir
# csdcsd
# d
# añadir
# sdcds
# d
# listar
# d
# 1. csdcsd
# 2. sdcds
# detener
# Terminando la sesión. ¡Hasta pronto!

# %%
canciones=dict()

while True: 
  comando=input() 
  if comando == "añadir": 
    cancion = input() 
    artista = input() 
    if artista not in canciones: 
      canciones[artista]=list() 
      canciones[artista].append(cancion)

  elif comando == "reproducir":
    artista = input()
    if artista in canciones:
        if len(canciones[artista]) > 0:
            cancion = canciones[artista].pop(0)
            print(f"Reproduciendo {cancion} de {artista}.")
            canciones[artista].append(cancion)
        else:
            print(f"No quedan canciones en cola.")
    else:
        print(f"El artista no tiene canciones registradas.")


  elif comando== "listar":
    artista = input()

    if artista in canciones:

        lista=canciones[artista]
        can=set(lista)
        n_canciones= len(can)

        for i in range (n_canciones):

            print(f"{i+1}. {lista[i]}")

    else:
        print(f"El artista no tiene canciones registradas.")       

       # Acceder al elemento i de la lista
# Imprimir la canción con el número "i + 1"

  elif comando== "detener":
    print("Terminando la sesión. ¡Hasta pronto!")
    break

  else:
    print("Comando no reconocido. Intente de nuevo:")
